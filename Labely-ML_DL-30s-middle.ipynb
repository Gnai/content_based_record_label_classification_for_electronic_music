# %% [markdown]
# ## A classification task: record label recognition

# %%
#Basic imports
import os
import matplotlib.pyplot as plt
import essentia.standard as ess
import essentia
import numpy as np
import sys

# %%
# Raw-data preprocess analysis parameters
fs = 44100
windowSize = 4096 * 4
hopSize = 4096 * 2
NRG_threshold_ratio = 0.01 #threshold expressed as ratio with respect to the maximum value
V_threshold = 0.01 #waveform threshold value
#Let's put in a container to be able to use as a single argument in function calls
params = {"fs":fs, "windowSize":windowSize, "hopSize":hopSize, "V_threshold":V_threshold}

# %% [markdown]
# ## Analysis and preprocessing of features

# %%
import pandas as pd

# %%
#Read 
file = 'data_30s_middle.csv'
data = pd.read_csv(file)
#Let's see the first lines of our data
print(data.shape)
data.head()
# Out:
# (2547, 111)
#    average_loudness  barkbands_crest.mean  barkbands_crest.stdev  \
# 0          0.985963             16.988277               6.152028
# 1          0.981879             16.154875               7.029408
# 2          0.987341             17.704046               5.994382
# 3          0.988173             18.196672               5.676707
# 4          0.974610             16.868780               5.965635
#
#    barkbands_flatness_db.mean  barkbands_flatness_db.stdev  \
# 0                    0.234508                     0.104749
# 1                    0.248749                     0.129977
# 2                    0.221113                     0.102747
# 3                    0.250346                     0.116325
# 4                    0.272079                     0.128965
#
#    barkbands_kurtosis.mean  barkbands_kurtosis.stdev  barkbands_skewness.mean  \
# 0                54.934834                111.080116                 4.672720
# 1               139.366715                373.698608                 6.428804
# 2                61.243366                 91.167221                 5.480647
# 3               131.642410                197.429703                 7.458259
# 4                67.502502                 97.909622                 5.588888
#
#    barkbands_skewness.stdev  barkbands_spread.mean  ...  \
# 0                  4.311407              22.171335  ...
# 1                  7.328341              24.018057  ...
# 2                  4.225255              16.820066  ...
# 3                  6.250255              25.070768  ...
# 4                  4.365337              18.521112  ...
#
#    tonal.hpcp_entropy.mean  tonal.hpcp_entropy.stdev  tonal.key_edma.strength  \
# 0                 1.935214                  0.825875                 0.671964
# 1                 2.261895                  0.816613                 0.467872
# 2                 2.214764                  0.626813                 0.407111
# 3                 2.151182                  0.751411                 0.538804
# 4                 2.586561                  0.888847                 0.626011
#
#    tonal.key_krumhansl.strength  tonal.key_temperley.strength  \
# 0                      0.650649                      0.601438
# 1                      0.477233                      0.485559
# 2                      0.422130                      0.442967
# 3                      0.536238                      0.531833
# 4                      0.628222                      0.619442
#
#    tonal.tuning_diatonic_strength  tonal.tuning_equal_tempered_deviation  \
# 0                        0.614866                               0.230020
# 1                        0.560867                               0.263837
# 2                        0.613699                               0.240900
# 3                        0.583113                               0.253850
# 4                        0.556919                               0.238008
#
#    tonal.tuning_frequency  tonal.tuning_nontempered_energy_ratio         label
# 0              434.193115                               0.894006  suaraarchive
# 1              434.193115                               0.917605  suaraarchive
# 2              434.193115                               0.956878  suaraarchive
# 3              434.193115                               0.934906  suaraarchive
# 4              434.193115                               0.894724  suaraarchive
#
# [5 rows x 111 columns]

# %%
data.isnull().sum().sum()#sums a matrix of True/False values obtained by checking if each value is Nan
# Out:
# 0

# %%
import seaborn as sns
# hue -> Grouping variable that will produce elements with different colors
# style -> Grouping variable that will produce elements with different styles
sns.relplot(x = "rhythm.bpm", y = "pitch_salience.stdev", hue = "label", data = data);

# %%
sns.pairplot(data.iloc[:, -7:], hue = "label");

# %%
#Descriptive statistics of the features:
data.describe()
# Out:
#        average_loudness  barkbands_crest.mean  barkbands_crest.stdev  \
# count       2547.000000           2547.000000            2547.000000
# mean           0.913043             15.180927               5.614914
# std            0.165287              2.885864               1.076160
# min            0.001562              4.632785               1.966245
# 25%            0.939197             13.283439               4.914629
# 50%            0.975071             15.292357               5.653038
# 75%            0.984565             17.228334               6.361290
# max            0.990343             23.036255               8.837737
#
#        barkbands_flatness_db.mean  barkbands_flatness_db.stdev  \
# count                 2547.000000                  2547.000000
# mean                     0.247572                     0.099920
# std                      0.073653                     0.033980
# min                      0.043752                     0.017622
# 25%                      0.196311                     0.076627
# 50%                      0.239995                     0.097434
# 75%                      0.291428                     0.120035
# max                      0.597628                     0.254839
#
#        barkbands_kurtosis.mean  barkbands_kurtosis.stdev  \
# count              2547.000000               2547.000000
# mean                 59.515610                124.315442
# std                  64.248412                166.299694
# min                  -0.639596                  0.784950
# 25%                  19.022895                 35.566545
# 50%                  40.931664                 79.184723
# 75%                  75.592430                156.789337
# max                 645.803650               4071.830078
#
#        barkbands_skewness.mean  barkbands_skewness.stdev  \
# count              2547.000000               2547.000000
# mean                  4.109969                  3.786611
# std                   1.978157                  2.025277
# min                  -0.812430                  0.382763
# 25%                   2.698751                  2.340080
# 50%                   3.893091                  3.440132
# 75%                   5.266065                  4.831747
# max                  14.290599                 19.029650
#
#        barkbands_spread.mean  ...  tonal.hpcp_crest.stdev  \
# count            2547.000000  ...             2547.000000
# mean               16.640644  ...                5.695293
# std                 8.796941  ...                1.148706
# min                 1.398662  ...                2.928567
# 25%                10.130668  ...                4.838696
# 50%                15.472783  ...                5.482456
# 75%                21.731068  ...                6.344826
# max                69.996796  ...               11.006345
#
#        tonal.hpcp_entropy.mean  tonal.hpcp_entropy.stdev  \
# count              2547.000000               2547.000000
# mean                  2.149318                  0.722405
# std                   0.358661                  0.096335
# min                   0.744395                  0.388070
# 25%                   1.903706                  0.657362
# 50%                   2.128037                  0.726230
# 75%                   2.393373                  0.783531
# max                   3.627443                  1.115771
#
#        tonal.key_edma.strength  tonal.key_krumhansl.strength  \
# count              2547.000000                   2547.000000
# mean                  0.596860                      0.596957
# std                   0.125883                      0.126319
# min                   0.198321                      0.199921
# 25%                   0.514329                      0.514680
# 50%                   0.610916                      0.608689
# 75%                   0.684641                      0.687663
# max                   0.898620                      0.900005
#
#        tonal.key_temperley.strength  tonal.tuning_diatonic_strength  \
# count                   2547.000000                     2547.000000
# mean                       0.593315                        0.530579
# std                        0.124623                        0.098200
# min                        0.200420                        0.222169
# 25%                        0.511081                        0.468424
# 50%                        0.601152                        0.534847
# 75%                        0.687411                        0.598843
# max                        0.903829                        0.844681
#
#        tonal.tuning_equal_tempered_deviation  tonal.tuning_frequency  \
# count                            2547.000000             2547.000000
# mean                                0.207897              436.653630
# std                                 0.079085                4.910714
# min                                 0.000433              431.193909
# 25%                                 0.168399              434.193115
# 50%                                 0.216110              434.193115
# 75%                                 0.256448              437.718536
# max                                 0.466130              456.570251
#
#        tonal.tuning_nontempered_energy_ratio
# count                            2547.000000
# mean                                0.872298
# std                                 0.095206
# min                                 0.574648
# 25%                                 0.838388
# 50%                                 0.897460
# 75%                                 0.938286
# max                                 0.999594
#
# [8 rows x 110 columns]

# %% [markdown]
# ### Preprocessing of the features
#
# **Normalisation of the features**

# %%
data_modif = data.copy()
#Let's use sklearn's preprocessing tools for applying normalisation to features
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
data_modif.iloc[:,:110] = min_max_scaler.fit_transform(data.iloc[:,:110].values)

# %%
data_modif.describe()
# Out:
#        average_loudness  barkbands_crest.mean  barkbands_crest.stdev  \
# count       2547.000000           2547.000000            2547.000000
# mean           0.921823              0.573161               0.530986
# std            0.167163              0.156811               0.156612
# min            0.000000              0.000000               0.000000
# 25%            0.948274              0.470056               0.429075
# 50%            0.984555              0.579215               0.536534
# 75%            0.994156              0.684412               0.639606
# max            1.000000              1.000000               1.000000
#
#        barkbands_flatness_db.mean  barkbands_flatness_db.stdev  \
# count                 2547.000000                  2547.000000
# mean                     0.367989                     0.346931
# std                      0.132977                     0.143246
# min                      0.000000                     0.000000
# 25%                      0.275439                     0.248738
# 50%                      0.354308                     0.336450
# 75%                      0.447169                     0.431726
# max                      1.000000                     1.000000
#
#        barkbands_kurtosis.mean  barkbands_kurtosis.stdev  \
# count              2547.000000               2547.000000
# mean                  0.093056                  0.030344
# std                   0.099388                  0.040849
# min                   0.000000                  0.000000
# 25%                   0.030416                  0.008544
# 50%                   0.064308                  0.019258
# 75%                   0.117925                  0.038320
# max                   1.000000                  1.000000
#
#        barkbands_skewness.mean  barkbands_skewness.stdev  \
# count              2547.000000               2547.000000
# mean                  0.325921                  0.182542
# std                   0.130977                  0.108612
# min                   0.000000                  0.000000
# 25%                   0.232482                  0.104968
# 50%                   0.311561                  0.163961
# 75%                   0.402469                  0.238591
# max                   1.000000                  1.000000
#
#        barkbands_spread.mean  ...  tonal.hpcp_crest.stdev  \
# count            2547.000000  ...             2547.000000
# mean                0.222192  ...                0.342511
# std                 0.128239  ...                0.142206
# min                 0.000000  ...                0.000000
# 25%                 0.127292  ...                0.236467
# 50%                 0.205168  ...                0.316162
# 75%                 0.296399  ...                0.422921
# max                 1.000000  ...                1.000000
#
#        tonal.hpcp_entropy.mean  tonal.hpcp_entropy.stdev  \
# count              2547.000000               2547.000000
# mean                  0.487305                  0.459440
# std                   0.124403                  0.132383
# min                   0.000000                  0.000000
# 25%                   0.402113                  0.370059
# 50%                   0.479924                  0.464697
# 75%                   0.571957                  0.543439
# max                   1.000000                  1.000000
#
#        tonal.key_edma.strength  tonal.key_krumhansl.strength  \
# count              2547.000000                   2547.000000
# mean                  0.569099                      0.567126
# std                   0.179755                      0.180434
# min                   0.000000                      0.000000
# 25%                   0.451247                      0.449602
# 50%                   0.589170                      0.583884
# 75%                   0.694447                      0.696690
# max                   1.000000                      1.000000
#
#        tonal.key_temperley.strength  tonal.tuning_diatonic_strength  \
# count                   2547.000000                     2547.000000
# mean                       0.558558                        0.495428
# std                        0.177170                        0.157748
# min                        0.000000                        0.000000
# 25%                        0.441650                        0.395583
# 50%                        0.569699                        0.502285
# 75%                        0.692329                        0.605087
# max                        1.000000                        1.000000
#
#        tonal.tuning_equal_tempered_deviation  tonal.tuning_frequency  \
# count                            2547.000000             2547.000000
# mean                                0.445493                0.215150
# std                                 0.169820                0.193515
# min                                 0.000000                0.000000
# 25%                                 0.360678                0.118189
# 50%                                 0.463128                0.118189
# 75%                                 0.549747                0.257115
# max                                 1.000000                1.000000
#
#        tonal.tuning_nontempered_energy_ratio
# count                            2547.000000
# mean                                0.700441
# std                                 0.224043
# min                                 0.000000
# 25%                                 0.620643
# 50%                                 0.759652
# 75%                                 0.855727
# max                                 1.000000
#
# [8 rows x 110 columns]

# %%
data_modif.label.value_counts()
# Out:
# littlehelpersarchive    283
# mordarchive             283
# suaraarchive            283
# kompaktarchive          283
# chillhoparchive         283
# ninjatunearchive        283
# stilvortalentarchive    283
# defectedarchive         283
# bar25archive            283
# Name: label, dtype: int64

# %%
#input values put in a matrix, there are 110 features
x = data_modif.iloc[:,:110]
#Creating output values
data_modif.label = pd.Categorical(data_modif.label)#convert to categorical data
y = np.array(data_modif.label.cat.codes) #create label encoded outputs
#Print the first sample
print("Features of the first sample: ", x.values)
print("Class of the first sample: ", y[0])
# Out:
# Features of the first sample:  [[0.99557008 0.67136755 0.6091519  ... 0.4929978  0.11818908 0.75152478]
#  [0.99143999 0.62608247 0.73683609 ... 0.56561272 0.11818908 0.80705955]
#  [0.99696371 0.71026069 0.58620991 ... 0.51636085 0.11818908 0.89947733]
#  ...
#  [0.26935917 0.35637131 0.54421669 ... 0.36910652 0.08856544 0.59855469]
#  [0.96238906 0.64610492 0.47671294 ... 0.39794332 0.11818908 0.59410074]
#  [0.97336043 0.60168928 0.51237137 ... 0.47491522 0.11818908 0.7897445 ]]
# Class of the first sample:  8

# %%
print(y)
print(y.shape)
# Out:
# [8 8 8 ... 6 6 6]
# (2547,)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=110)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(110,'Score'))  #print k best features
# Out:
#                                      Specs       Score
# 49                 silence_rate_60dB.stdev  139.452398
# 75                  spectral_rolloff.stdev   81.973322
# 45                 silence_rate_20dB.stdev   76.500651
# 21                 erbbands_skewness.stdev   72.313657
# 10                  barkbands_spread.stdev   69.536002
# ..                                     ...         ...
# 54                  spectral_decrease.mean    3.224645
# 89  rhythm.bpm_histogram_first_peak_weight    2.697933
# 65    spectral_energyband_middle_low.stdev    2.633863
# 0                         average_loudness    1.362112
# 44                  silence_rate_20dB.mean    0.506580
#
# [110 rows x 2 columns]

# %%
X_new = bestfeatures.fit_transform(x, y)

# %%
print ( X_new.shape)
# Out:
# (2547, 110)

# %%
from numpy import save
save('y.npy', y)

# %% [markdown]
# ## SVM TRAINING AND TESTING

# %%
#All output values: 
print(y)
# Out:
# [8 8 8 ... 6 6 6]

# %% [markdown]
# **Splitting data into train and test subsets**

# %%
#Let's split data into test and train sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size = 0.20, random_state = 42) #random_state = 20 or 42

# %%
print("Size of train features matrix: ",X_train.shape, ", Size of train output vector: ",y_train.shape)
print("Size of test features matrix: ",X_test.shape, ", Size of test output vector: ",y_test.shape)
# Out:
# Size of train features matrix:  (2037, 110) , Size of train output vector:  (2037,)
# Size of test features matrix:  (510, 110) , Size of test output vector:  (510,)

# %% [markdown]
# **Defining the machine learning model and training it**
#
# Now we can train a machine learning model. Let's pick a Support Vector Machine (SVM) model and feed our data to train it.

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate 
#clf = svm.SVC(gamma = 1 / (X_train.shape[-1] * X_train.var()))
tuned_parameters = [{'gamma': [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1]}]
                    
 #cross-validation for gamma:
clf = GridSearchCV(svm.SVC(), tuned_parameters, cv=10) #C-Support Vector Classification based on libsvm

scores = cross_validate (clf, X_new, y, cv=10, return_estimator=True)
clf= scores ['estimator'][int(np.argmax(scores['test_score']))]
clf.fit(X_train, y_train)   


print(clf.best_params_)
# Out:
# {'gamma': 1}

# %% [markdown]
# **Testing the model**

# %%
y_pred = clf.predict(X_test)

# %%
#Let's check for each sample in the test set if prediction matches the true class information
y_test == y_pred
# Out:
# array([False,  True, False, False,  True,  True,  True,  True,  True,
#        False,  True,  True, False,  True,  True, False, False, False,
#         True,  True, False, False,  True,  True, False,  True,  True,
#         True, False,  True,  True, False,  True, False,  True, False,
#        False,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True, False,  True, False, False,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False,  True, False,  True,  True, False, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False, False,  True,
#        False,  True,  True, False, False,  True,  True, False, False,
#         True, False,  True, False, False, False,  True, False,  True,
#        False, False, False,  True,  True,  True,  True,  True, False,
#        False,  True, False,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True, False, False,
#         True,  True,  True,  True, False,  True,  True,  True, False,
#        False, False, False,  True,  True, False,  True,  True,  True,
#        False,  True,  True, False, False,  True,  True,  True, False,
#        False,  True,  True, False,  True, False, False, False,  True,
#        False, False, False, False, False, False, False,  True,  True,
#         True, False,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True, False,  True, False, False,  True, False,
#         True,  True,  True, False, False,  True, False, False, False,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True, False, False,  True, False, False,  True,  True, False,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True, False, False, False, False,  True, False, False,
#         True,  True,  True,  True,  True, False,  True, False, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False,  True,  True,  True, False, False, False,  True,  True,
#         True,  True,  True, False, False, False,  True,  True,  True,
#        False, False, False,  True, False, False,  True,  True,  True,
#        False, False,  True, False,  True, False,  True,  True,  True,
#         True,  True,  True, False, False, False, False, False, False,
#        False,  True,  True,  True, False,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True,  True,  True, False,  True,  True, False,
#        False,  True,  True,  True,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#        False, False,  True, False, False,  True, False,  True, False,
#         True, False, False,  True,  True,  True, False,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True, False, False,  True, False,  True,  True, False,
#         True, False,  True, False, False, False, False,  True,  True,
#         True,  True,  True,  True, False, False,  True,  True, False,
#        False, False,  True,  True, False, False, False, False,  True,
#         True, False, False, False, False, False,  True,  True,  True,
#         True, False,  True,  True,  True, False,  True, False,  True,
#         True, False,  True,  True, False, False,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#        False,  True, False,  True, False,  True, False, False, False,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True, False,  True, False, False])

# %%
#Data is balanced, so you can use accuracy as a measure:
print("accuracy: ", np.sum(y_test == y_pred)/len(y_test))
# Out:
# accuracy:  0.5666666666666667

# %% [markdown]
# **Observation:** the accuracy looks good but keep in mind that we have a small dataset and simply obtained a random subset for testing

# %% [markdown]
# As the final step, let's also print the **confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

classes = np.unique(data_modif.label)
conf_mat = pd.DataFrame(confusion_matrix(y_test, y_pred), columns = classes, index = classes)
conf_mat.index.name = 'Actual'
conf_mat.columns.name = 'Predicted'
plt.figure(figsize = (7, 5))
sns.set(font_scale = 1)
sns.heatmap(conf_mat, cmap = "Oranges", annot_kws = {"size": 12}, annot = True);

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.41      0.47        66
#            1       0.91      0.80      0.85        60
#            2       0.53      0.67      0.59        57
#            3       0.41      0.35      0.38        51
#            4       0.64      0.78      0.70        60
#            5       0.67      0.72      0.69        60
#            6       0.36      0.49      0.42        43
#            7       0.58      0.50      0.54        56
#            8       0.40      0.33      0.37        57
#
#     accuracy                           0.57       510
#    macro avg       0.56      0.56      0.56       510
# weighted avg       0.57      0.57      0.56       510

# %%
import sklearn.metrics
sklearn.metrics.hamming_loss(y_test, y_pred, sample_weight=None)
# Out:
# 0.43333333333333335

# %% [markdown]
# ## Other ML Frameworks

# %%
import warnings
warnings.filterwarnings('ignore')#suppress warnings
#importing various classifiers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.naive_bayes import GaussianNB

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    #SVC(gamma = 1 / (X_train.shape[-1] * X_train.var())),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    MLPClassifier(alpha=1, max_iter=1000),
    GaussianNB()]

names = ["KNN", "Linear SVM", "Gaussian Process","Neural Net", "Naive Bayes"] #"RBF SVM"

#Creating empty list of scores for each classifier, we will append test results to these lists 
scores = {}
for name in names:
    scores[name] = []

#Let's split our data into test and train
x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size = 0.20, random_state = 1)

#Let's run 10 random experiments, collect scores for each classifier 
num_tests = 10
for iteration_number in range(num_tests):
    x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size = 1/num_tests, random_state = iteration_number)
    #normalisation of the data (learned from training data, applied to test data)
    scaler = StandardScaler().fit(x_train)
    norm_x_train = scaler.transform(x_train)
    norm_x_val = scaler.transform(x_val)
    
    # test over each classifier
    for name, clf in zip(names, classifiers):
        clf.fit(norm_x_train, y_train)#train
        score = clf.score(norm_x_val, y_val)#test
        scores[name].append(score)

for name, score in scores.items():
    print("{0}: acc = {1:1.2f}, +-{2:1.2f},\tvalues: {3}".format(name, np.mean(score), np.std(score), np.around(score, decimals = 2)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-02498ac3208c> in <module>
#      41     # test over each classifier
#      42     for name, clf in zip(names, classifiers):
# ---> 43         clf.fit(norm_x_train, y_train)#train
#      44         score = clf.score(norm_x_val, y_val)#test
#      45         scores[name].append(score)
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/gaussian_process/_gpc.py in fit(self, X, y)
#     657                                  % self.multi_class)
#     658
# --> 659         self.base_estimator_.fit(X, y)
#     660
#     661         if self.n_classes_ > 2:
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/multiclass.py in fit(self, X, y)
#     237                 "not %s" % self.label_binarizer_.classes_[i],
#     238                 self.label_binarizer_.classes_[i]])
# --> 239             for i, column in enumerate(columns))
#     240
#     241         return self
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/multiclass.py in _fit_binary(estimator, X, y, classes)
#      77     else:
#      78         estimator = clone(estimator)
# ---> 79         estimator.fit(X, y)
#      80     return estimator
#      81
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/gaussian_process/_gpc.py in fit(self, X, y)
#     214             optima = [self._constrained_optimization(obj_func,
#     215                                                      self.kernel_.theta,
# --> 216                                                      self.kernel_.bounds)]
#     217
#     218             # Additional runs are performed from log-uniform chosen initial
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/gaussian_process/_gpc.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     448             opt_res = scipy.optimize.minimize(
#     449                 obj_func, initial_theta, method="L-BFGS-B", jac=True,
# --> 450                 bounds=bounds)
#     451             _check_optimize_result("lbfgs", opt_res)
#     452             theta_opt, func_min = opt_res.x, opt_res.fun
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/gaussian_process/_gpc.py in obj_func(theta, eval_gradient)
#     205                 if eval_gradient:
#     206                     lml, grad = self.log_marginal_likelihood(
# --> 207                         theta, eval_gradient=True, clone_kernel=False)
#     208                     return -lml, -grad
#     209                 else:
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/sklearn/gaussian_process/_gpc.py in log_marginal_likelihood(self, theta, eval_gradient, clone_kernel)
#     374         # XXX: Get rid of the np.diag() in the next line
#     375         R = W_sr[:, np.newaxis] * cho_solve((L, True), np.diag(W_sr))  # Line 7
# --> 376         C = solve(L, W_sr[:, np.newaxis] * K)  # Line 8
#     377         # Line 9: (use einsum to compute np.diag(C.T.dot(C))))
#     378         s_2 = -0.5 * (np.diag(K) - np.einsum('ij, ij -> j', C, C)) \
#
# /mnt/vmdata/users/gnaimeh/geo/lib/python3.6/site-packages/scipy/linalg/basic.py in solve(a, b, sym_pos, lower, overwrite_a, overwrite_b, debug, check_finite, assume_a, transposed)
#     216         _solve_check(n, info)
#     217         x, info = getrs(lu, ipvt, b1,
# --> 218                         trans=trans, overwrite_b=overwrite_b)
#     219         _solve_check(n, info)
#     220         rcond, info = gecon(lu, anorm, norm=norm)
#
# KeyboardInterrupt:

# %% [markdown]
# ### How about Deep Learning?
#
# We would often prefer deep learning based architectures when the data size is large. See Andrew Ng's figure from his [Coursera course](https://www.coursera.org/learn/neural-networks-deep-learning/):
#
# <img src=https://raw.githubusercontent.com/mbadry1/DeepLearning.ai-Summary/master/1-%20Neural%20Networks%20and%20Deep%20Learning/Images/11.png width="700">
#
# The data size in our case is small and the methods examplified above are just fine. Below, for the sake of presenting an example using a deep learning architecture, we build (with Keras) and train a DNN using the same features. For cases with larger data sets, feature extraction step can be dropped and end-to-end systems(audio->label) can be designed. Due to the size of our data, we will stick with our features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#Let's start by splitting our data 
X_train_val, X_test, y_train_val, y_test = train_test_split(X_new, y, test_size = 0.20, random_state = 42)


#..and apply normalisation
scaler = StandardScaler().fit(X_train_val)
norm_x_train_val = scaler.transform(X_train_val)
norm_x_test = scaler.transform(X_test)

# %% [markdown]
# Our neural network will have 4 neurons at the output layer each of which will output the estimated probability of the sample belonging to a class. So, let's convert our labels to **one-hot encoding** to fit to that representation.
# Example: a sample belonging to the 'violin' class is represented with 3 (integer encoded) will be represented with  [0 0 0 1]. Similarly, a 'ebclar' sample represented with with 0 will be represented with [1 0 0 0]

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)
y_train_val_onehot = onehot_encoder.fit_transform(y_train_val.reshape(len(y_train_val), 1))
y_test_onehot = onehot_encoder.fit_transform(y_test.reshape(len(y_test), 1))
print("One-hot encoded y_train_val shape = ", y_train_val_onehot.shape)
print("One-hot encoded y_test shape = ", y_test_onehot.shape)
# Out:
# One-hot encoded y_train_val shape =  (2037, 9)
# One-hot encoded y_test shape =  (510, 9)

# %% [markdown]
# **Let's define our deep learning architecture**

# %%
# !pip3 install keras
# Out:
# Requirement already satisfied: keras in ./geo/lib/python3.6/site-packages (2.3.1)
# Requirement already satisfied: six>=1.9.0 in ./geo/lib/python3.6/site-packages (from keras) (1.14.0)
# Requirement already satisfied: pyyaml in ./geo/lib/python3.6/site-packages (from keras) (5.3)
# Requirement already satisfied: keras-applications>=1.0.6 in ./geo/lib/python3.6/site-packages (from keras) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in ./geo/lib/python3.6/site-packages (from keras) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in ./geo/lib/python3.6/site-packages (from keras) (1.18.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in ./geo/lib/python3.6/site-packages (from keras) (1.1.0)
# Requirement already satisfied: h5py in ./geo/lib/python3.6/site-packages (from keras) (2.10.0)

# %%
# !pip3 install tensorflow
# Out:
# Requirement already satisfied: tensorflow in ./geo/lib/python3.6/site-packages (2.2.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in ./geo/lib/python3.6/site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in ./geo/lib/python3.6/site-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: six>=1.12.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.27.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.18.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./geo/lib/python3.6/site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: astunparse==1.6.3 in ./geo/lib/python3.6/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast==0.3.3 in ./geo/lib/python3.6/site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in ./geo/lib/python3.6/site-packages (from tensorflow) (0.1.8)
# Requirement already satisfied: protobuf>=3.8.0 in ./geo/lib/python3.6/site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.16.1)
# Requirement already satisfied: setuptools>=41.0.0 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (46.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./geo/lib/python3.6/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.6.0.post3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./geo/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in ./geo/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in ./geo/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2020.4.5.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./geo/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./geo/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.25.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./geo/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in ./geo/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in ./geo/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./geo/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./geo/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)

# %%
from keras.models import Sequential
from keras import layers

def compose_model(num_features):
    
    model = Sequential()

    # Input layer 
    model.add(layers.BatchNormalization(name='InputLayer', input_shape=(num_features,)))
    
    # 1. hidden layer
    model.add(layers.Dense(name='HiddenLayer_1', units = 110))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('tanh'))
    model.add(layers.Dropout(0.3))

    # 2. hidden layyer
    model.add(layers.Dense(name='HiddenLayer_2', units = 55))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))

    # Output layer
    model.add(layers.Dense(name='Output_layer', units = 9))
    model.add(layers.Activation('softmax'))
    
    return model

model = compose_model(X_train_val.shape[1])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# You can have a look at the summary of the model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# InputLayer (BatchNormalizati (None, 110)               440
# _________________________________________________________________
# HiddenLayer_1 (Dense)        (None, 110)               12210
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 110)               440
# _________________________________________________________________
# activation_1 (Activation)    (None, 110)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 110)               0
# _________________________________________________________________
# HiddenLayer_2 (Dense)        (None, 55)                6105
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 55)                220
# _________________________________________________________________
# activation_2 (Activation)    (None, 55)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 55)                0
# _________________________________________________________________
# Output_layer (Dense)         (None, 9)                 504
# _________________________________________________________________
# activation_3 (Activation)    (None, 9)                 0
# =================================================================
# Total params: 19,919
# Trainable params: 19,369
# Non-trainable params: 550
# _________________________________________________________________

# %% [markdown]
# Let's pick an optimizer, compile the model and train the network

# %%
model.compile(optimizer = 'Adam', loss = 'categorical_crossentropy', metrics = ['acc'])
summary = model.fit(X_train_val, y_train_val_onehot, batch_size = 50, epochs = 50, validation_split=0.2, verbose=0)

# %% [markdown]
# Testing the trained model

# %%
score = model.evaluate(X_test, y_test_onehot, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.2069114399891274
# Test accuracy: 0.5647059082984924

# %% [markdown]
# It is a good and common practice to check the learning curves

# %%
# summarize history for accuracy
plt.plot(summary.history['acc'])
plt.plot(summary.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# summarize history for loss
plt.plot(summary.history['loss'])
plt.plot(summary.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
import sklearn
y=model.predict(X_test)
print(np.argmax(y))
# Out:
# 2692

# %%
y_pred = y.argmax(axis=1)

# %%
sklearn.metrics.f1_score(y_test, y_pred, average='micro')
# Out:
# 0.5647058823529412

# %%
import sklearn.metrics
sklearn.metrics.hamming_loss(y_test, y_pred, sample_weight=None)
# Out:
# 0.43529411764705883

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

classes = np.unique(data_modif.label)
conf_mat = pd.DataFrame(confusion_matrix(y_test, y_pred), columns = classes, index = classes)
conf_mat.index.name = 'Actual'
conf_mat.columns.name = 'Predicted'
plt.figure(figsize = (7, 5))
sns.set(font_scale = 1)
sns.heatmap(conf_mat, cmap = "Oranges", annot_kws = {"size": 12}, annot = True);

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.39      0.42        66
#            1       0.90      0.90      0.90        60
#            2       0.49      0.51      0.50        57
#            3       0.44      0.41      0.42        51
#            4       0.66      0.72      0.69        60
#            5       0.73      0.73      0.73        60
#            6       0.41      0.51      0.45        43
#            7       0.53      0.46      0.50        56
#            8       0.41      0.40      0.41        57
#
#     accuracy                           0.56       510
#    macro avg       0.56      0.56      0.56       510
# weighted avg       0.56      0.56      0.56       510

# %% [markdown]
# ## PREDICTIONS

# %% [markdown]
# ## Model Prediction on New Data

# %%
model.save("boc_30s/kerasmodel30s.h5")
print("Model Saved")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2008c68c6f00> in <module>
# ----> 1 model.save("boc_30s/kerasmodel30s.h5")
#       2 print("Model Saved")
#
# NameError: name 'model' is not defined
